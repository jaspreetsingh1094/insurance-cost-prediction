# %% [markdown]
# # IMPORTING LIBRARIES AND DATASETS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# read the csv file 
insurance_df = pd.read_csv('insurance.csv')

# %%
insurance_df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # PERFORMING EXPLORATORY DATA ANALYSIS

# %%
# check if there are any Null values
sns.heatmap(insurance_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <AxesSubplot: >

# %%
# check if there are any Null values
insurance_df.isnull().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Check the dataframe info
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Grouping by region to see any relationship between region and charges
# Seems like south east region has the highest charges and body mass index
df_region = insurance_df.groupby(by='region').mean(numeric_only=True)
df_region
# Out:
#                  age        bmi  children       charges
# region
# northeast  39.268519  29.173503  1.046296  13406.384516
# northwest  39.196923  29.199785  1.147692  12417.575374
# southeast  38.939560  33.355989  1.049451  14735.411438
# southwest  39.455385  30.596615  1.141538  12346.937377

# %% [markdown]
# # Group data by 'age' and examine the relationship between 'age' and 'charges'

# %%
df_age = insurance_df.groupby(by='age').mean(numeric_only=True)
df_age
# Out:
#            bmi  children       charges
# age
# 18   31.326159  0.449275   7086.217556
# 19   28.596912  0.426471   9747.909335
# 20   30.632759  0.862069  10159.697736
# 21   28.185714  0.785714   4730.464330
# 22   31.087679  0.714286  10012.932802
# 23   31.454464  1.000000  12419.820040
# 24   29.142679  0.464286  10648.015962
# 25   29.693929  1.285714   9838.365311
# 26   29.428929  1.071429   6133.825309
# 27   29.333571  0.964286  12184.701721
# 28   29.482143  1.285714   9069.187564
# 29   29.383148  1.259259  10430.158727
# 30   30.557593  1.555556  12719.110358
# 31   29.918333  1.407407  10196.980573
# 32   31.597692  1.269231   9220.300291
# 33   31.163077  1.538462  12351.532987
# 34   30.274038  1.153846  11613.528121
# 35   31.394800  1.680000  11307.182031
# 36   29.374200  1.240000  12204.476138
# 37   31.216600  1.520000  18019.911877
# 38   28.996600  1.480000   8102.733674
# 39   29.910200  2.200000  11778.242945
# 40   30.139074  1.592593  11772.251310
# ...

# %% [markdown]
# # PERFORMING DATA VISUALIZATION

# %%
insurance_df[['age', 'gender', 'bmi', 'children', 'smoker', 'charges']].hist(bins = 30, figsize = (12, 12), color = 'b');

# %%
fig = px.histogram(insurance_df,
                   x='charges',
                   marginal='box',
                   color='smoker',
                   color_discrete_sequence=['red', 'blue'],
                   title='Annual Mecical Insurance Charges')
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.histogram(insurance_df, 
                   x='age', 
                   marginal='box', 
                   nbins=47, 
                   title='Distribution of Age')
fig.update_layout(bargap=0.1)
fig.show()

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'age', y = 'charges', data = insurance_df).set(title='Effect of Age on the Mecical Insurance Cost')
plt.show()

# %%
fig = px.histogram(insurance_df, 
                   x='bmi', 
                   marginal='box', 
                   title='Distribution of BMI (Body Mass Index)')
fig.update_layout(bargap=0.1)
fig.show()

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'bmi', y = 'charges', data = insurance_df).set(title='Effect of BMI on the Mecical Insurance Cost')
plt.show()

# %%
fig = px.histogram(insurance_df,
                   x = 'charges',
                   color = 'gender',
                   color_discrete_sequence = ["blue","red"],
                   title = 'Different charges over genders'
               
)
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.histogram(insurance_df,
                  x = "charges",
                  marginal = 'box', 
                  color="region",
                  title = "Insurance cost over different regions of U.S.A")
fig.update_layout(bargap=0.1)
fig.show()

# %%
px.histogram(insurance_df,x='gender',y = 'charges',color = 'region')

# %%
insurance_df.smoker.value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
px.histogram(insurance_df,
             x='smoker',
             color='gender',
             title='Smoker')

# %%
sns.barplot(data = insurance_df,x = 'gender',y = 'charges',hue = "smoker")
# Out:
# <AxesSubplot: xlabel='gender', ylabel='charges'>

# %%
fig = px.scatter(insurance_df, 
                 x='age', 
                 y='charges', 
                 color='smoker', 
                 opacity=0.8, 
                 hover_data=['gender'], 
                 title='Age vs. Charges')
fig.update_traces(marker_size=5)
fig.show()

# %%
fig = px.scatter(insurance_df, 
                 x='bmi', 
                 y='charges', 
                 color='smoker', 
                 opacity=0.8, 
                 hover_data=['gender'], 
                 title='BMI vs. Charges')
fig.update_traces(marker_size=5)
fig.show()

# %%
fig = px.histogram(insurance_df,
                  x = 'charges',
                   marginal ="box",
                  color = 'children',
                  title = 'charges incurred by children')
fig.update_layout(bargap=0.1)
fig.show()

# %%
px.violin(insurance_df,x = 'children',y = 'charges')

# %% [markdown]
# # PERFORMING FEATURE ENGINEERING

# %%
# Check unique values in the 'gender' column
insurance_df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# convert categorical variable to numerical
insurance_df['gender'] = insurance_df['gender'].apply(lambda x: 0 if x == 'female' else 1)

# %%
insurance_df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19       0  27.900         0    yes  southwest  16884.92400
# 1   18       1  33.770         1     no  southeast   1725.55230
# 2   28       1  33.000         3     no  southeast   4449.46200
# 3   33       1  22.705         0     no  northwest  21984.47061
# 4   32       1  28.880         0     no  northwest   3866.85520

# %%
# Check the unique values in the 'smoker' column
insurance_df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
# Convert categorical variable to numerical 
insurance_df['smoker'] = insurance_df['smoker'].apply(lambda x: 0 if x == 'no' else 1)

# %%
insurance_df.head()
# Out:
#    age  gender     bmi  children  smoker     region      charges
# 0   19       0  27.900         0       1  southwest  16884.92400
# 1   18       1  33.770         1       0  southeast   1725.55230
# 2   28       1  33.000         3       0  southeast   4449.46200
# 3   33       1  22.705         0       0  northwest  21984.47061
# 4   32       1  28.880         0       0  northwest   3866.85520

# %%
# Check unique values in 'region' column
insurance_df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_dummies = pd.get_dummies(insurance_df['region'], drop_first = True)

# %%
region_dummies
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
insurance_df = pd.concat([insurance_df, region_dummies], axis = 1)

# %%
insurance_df.head()
# Out:
#    age  gender     bmi  children  smoker     region      charges  northwest  \
# 0   19       0  27.900         0       1  southwest  16884.92400          0
# 1   18       1  33.770         1       0  southeast   1725.55230          0
# 2   28       1  33.000         3       0  southeast   4449.46200          0
# 3   33       1  22.705         0       0  northwest  21984.47061          1
# 4   32       1  28.880         0       0  northwest   3866.85520          1
#
#    southeast  southwest
# 0          0          1
# 1          1          0
# 2          1          0
# 3          0          0
# 4          0          0

# %% [markdown]
# # Finding which feature has the most positive correlation with charges?

# %%
insurance_df.corr(numeric_only = True)
plt.figure(figsize = (10, 10))
sns.heatmap(insurance_df.corr(numeric_only = True), annot = True)
# smoker and age have positive correlations with charges
# Out:
# <AxesSubplot: >

# %%
# CREATING CATEGORIES OF CHARGES
insurance_df['charges_code'] = insurance_df['charges'].apply(lambda x: 1 if (x > 0 and x < 15000) 
                                                                        else (2 if (x > 15000 and x < 30000) 
                                                                        else (3 if (x > 30000 and x < 45000) 
                                                                        else 4))
                                                            )

# %%
insurance_df
# Out:
#       age  gender     bmi  children  smoker     region      charges  \
# 0      19       0  27.900         0       1  southwest  16884.92400
# 1      18       1  33.770         1       0  southeast   1725.55230
# 2      28       1  33.000         3       0  southeast   4449.46200
# 3      33       1  22.705         0       0  northwest  21984.47061
# 4      32       1  28.880         0       0  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50       1  30.970         3       0  northwest  10600.54830
# 1334   18       0  31.920         0       0  northeast   2205.98080
# 1335   18       0  36.850         0       0  southeast   1629.83350
# 1336   21       0  25.800         0       0  southwest   2007.94500
# 1337   61       0  29.070         0       1  northwest  29141.36030
#
#       northwest  southeast  southwest  charges_code
# 0             0          0          1             2
# ...

# %%
# Dropping the original 'region' column 
insurance_df.drop(['region'], axis = 1, inplace = True)
insurance_df.head()
# Out:
#    age  gender     bmi  children  smoker      charges  northwest  southeast  \
# 0   19       0  27.900         0       1  16884.92400          0          0
# 1   18       1  33.770         1       0   1725.55230          0          1
# 2   28       1  33.000         3       0   4449.46200          0          1
# 3   33       1  22.705         0       0  21984.47061          1          0
# 4   32       1  28.880         0       0   3866.85520          1          0
#
#    southwest  charges_code
# 0          1             2
# 1          0             1
# 2          0             1
# 3          0             2
# 4          0             1

# %% [markdown]
# # CREATING TRAINING AND TESTING DATASET FOR CLASSIFICATION

# %%
insurance_df.columns
# Out:
# Index(['age', 'gender', 'bmi', 'children', 'smoker', 'charges', 'northwest',
#        'southeast', 'southwest', 'charges_code'],
#       dtype='object')

# %%
X = insurance_df.drop(columns =['charges','charges_code'])
y = insurance_df['charges_code']

# %%
X
# Out:
#       age  gender     bmi  children  smoker  northwest  southeast  southwest
# 0      19       0  27.900         0       1          0          0          1
# 1      18       1  33.770         1       0          0          1          0
# 2      28       1  33.000         3       0          0          1          0
# 3      33       1  22.705         0       0          1          0          0
# 4      32       1  28.880         0       0          1          0          0
# ...   ...     ...     ...       ...     ...        ...        ...        ...
# 1333   50       1  30.970         3       0          1          0          0
# 1334   18       0  31.920         0       0          0          0          0
# 1335   18       0  36.850         0       0          0          1          0
# 1336   21       0  25.800         0       0          0          0          1
# 1337   61       0  29.070         0       1          1          0          0
#
# [1338 rows x 8 columns]

# %%
y
# Out:
# 0       2
# 1       1
# 2       1
# 3       2
# 4       1
#        ..
# 1333    1
# 1334    1
# 1335    1
# 1336    1
# 1337    2
# Name: charges_code, Length: 1338, dtype: int64

# %%
X.shape
# Out:
# (1338, 8)

# %%
y.shape
# Out:
# (1338,)

# %%
# Initiate another "object" of KNeighborsClassifier "class" with k=3: -- CLASSIFICATION

from sklearn.neighbors import KNeighborsClassifier
k = 3
knnTrainingModel = KNeighborsClassifier(n_neighbors=k) # name of the object is arbitrary!
print("value of k right now is 3")
# Out:
# value of k right now is 3

# %%
# We use the method "fit" of the object along with training dataset and labels to train this model:

knnTrainingModel.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# # Splitting the data into 20% Testing and 80% Training

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1070, 8)
# (268, 8)

# %% [markdown]
# # Knn CLASSIFICATION

# %%
# Testing set:
predictYKnn = knnTrainingModel.predict(X)
print(predictYKnn)
# Out:
# [2 1 1 ... 1 1 2]

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y, predictYKnn)
print(accuracy)
# Out:
# 0.8445440956651719

# %%
print("Repeating the last step with values K=1, K=5, K=7, K=11, K=15, K=27, K=59")
for k in (1,5,7,11,15,27,59):

    knnTrainingModel = KNeighborsClassifier(n_neighbors=k)
    trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.4, random_state=6)
    knnTrainingModel.fit(X, y)
    predictYKnn = knnTrainingModel.predict(X)
    accuracy = accuracy_score(y, predictYKnn)
    
    print(f'For k = {k}, the accuracy is {accuracy}')
# Out:
# Repeating the last step with values K=1, K=5, K=7, K=11, K=15, K=27, K=59
# For k = 1, the accuracy is 0.9992526158445441
# For k = 5, the accuracy is 0.7982062780269058
# For k = 7, the accuracy is 0.7645739910313901
# For k = 11, the accuracy is 0.7548579970104634
# For k = 15, the accuracy is 0.7399103139013453
# For k = 27, the accuracy is 0.7331838565022422
# For k = 59, the accuracy is 0.7324364723467862

# %%
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

# %%
y = y.reshape(-1,1)

# %%
y.shape
# Out:
# (1338, 1)

# %%
# scaling the data before feeding the model
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_x = StandardScaler()
X = scaler_x.fit_transform(X)

scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)

# %%
# Creating training and testing dataset with scaled data for linear regression

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1070, 8)
# (268, 8)

# %% [markdown]
# # Train and evaluate a Linear Regression Model in Scikit-Learn

# %%
# using linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

regresssion_model_sklearn = LinearRegression()
regresssion_model_sklearn.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regresssion_model_sklearn_accuracy = regresssion_model_sklearn.score(X_test, y_test)
regresssion_model_sklearn_accuracy
# Out:
# 0.670853795045653

# %%
y_predict = regresssion_model_sklearn.predict(X_test)

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 268

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt


RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 0.431
# MSE = 0.18588716
# MAE = 0.2927546
# R2 = 0.6708537589610251
# Adjusted R2 = 0.6606870797011339
